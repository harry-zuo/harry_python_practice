# %% [markdown]
# ## 数据结构研究内容
# ![image.png](attachment:7793a939-8346-4873-9109-1094bb28a823.png)

# %% [markdown]
# ## 计算机作为数值计算工具
# - 弹道计算：在军事领域，早期计算机的一个重要应用是进行弹道计算。弹道计算涉及预测炮弹、导弹或其他投射物的飞行轨迹。这需要解决复杂的微分方程，计算出投射物在不同时间点的位置、速度和加速度。这些计算对于确保武器的准确性和有效性至关重要。例如，世界上第一台通用计算机ENIAC（电子数值积分和计算机）就是为美国陆军军械部开发的，用于计算炮弹的弹道轨迹。
# - 台风预测：
#   - 提高预测准确性：利用超级计算机进行数值模拟，可以对台风的路径、强度和发展趋势进行更为精确的预测。例如，日本的理化学研究所和气象厅团队使用超级计算机“京”分析气象卫星数据，捕捉云层高度和厚度，从而提高了台风和暴雨预测的准确性。
#   - 增强数据处理能力：超级计算机能够处理大量的气象数据，包括卫星观测数据、雷达数据、地面观测数据等，这些数据对于台风预测至关重要。通过高性能计算技术，可以实时处理和分析这些数据，为预测提供最新的信息。
#   - 模拟复杂气象系统：台风的形成和发展受到多种气象因素的影响，包括温度、湿度、气压、风向和风速等。超级计算机能够模拟这些复杂的相互作用，提供更为细致的天气预报和气候预测。

# %% [markdown]
# ## 随着计算机领域的扩展，计算机不报备越来越多的用于”非数值“计算
# - 学生学籍管理系统
#   - ![image.png](attachment:37f046e6-3123-444b-b9f2-96aff12d144a.png)
#
# - 管理系统研究内容：
#   - 操作对象： 每位学生的信息（学号、姓名、性别、籍贯、专业）
#   - 操作算法： 查询、插入、修改、删除等
#   - 操作对象之间的关系：线性关系
#   - 数据结构：线性数据结构、线性表

# %% [markdown]
# ## 类型信息处理的内容越来越多，抽象出来总结：
# - 操作对象：若干行数据记录
# - 操作算法：查询、插入、修改、删除等
# - 操作对象的关系：线性关系
# - 数据额结构：线性数据结构、线性表
#
# 总结：操作对象之间是线性关系

# %% [markdown]
# ## 思考题 围棋人机对弈
# - ![image.png](attachment:e4dacafb-ea19-4cc4-8b2b-6c0270a60741.png)
# - 计算机根据当前格局，计算算法后得出下一步的派生格局
# - 至于选择哪个格局，则需要根据策略一步一步演算预测棋局发展的趋势，甚至最后结局
# - 计算机的操作对象：各种棋局状态，即描述期盼的格局信息
# - 计算机的算法：走棋，即选择一种策略使得棋局状态发生变化（由一个格局派生出另一个格局）
#
# 总结：操作对象之间的关系：非线性、树

# %% [markdown]
# ## 思考题：文件系统的系统结构图
# - ![image.png](attachment:c1382367-09dc-41a0-b765-097b200fe133.png)
# - 磁盘根目录下有很多子目录及文件没每个子目录里有可以包含多个子目录及文件
# - 每个子目录只有一个父目录，依次类推
#
# 总结：一种典型的树形结构，数据与数据成一对多的关系。

# %% [markdown]
# ## 思考题：地图导航-求最快路径
# - ![image.png](attachment:475a30ce-9af9-4696-a1d3-d5f9189b922c.png)
# - 问题：找到图中两点之间最短路径或最经济路径
# - 操作对象：各地点及路的信息如权重等等
# - 计算机算法：设置信号灯，求出各个可同时同行的路的集合
# - 对象之间的关系：非线性关系，网状结构，图
#
# 总结：网状关系，操作对象是多对多关系

# %% [markdown]
# # 综上所述
# - 这些问题的共性都是无法用数学的公式或方程来描述，是一些“非数值计算”的程序设计问题
# - 描述非数值计算问题的数学模型不是数学方程，而是诸如表、树、图之类的具有逻辑关系的数据
# - 数据结构是一门研究非数值计算的程序设计中计算机的操作对象及他们之间的关系和操作的学科
