# %% [markdown]
# # 线性表的案例引入

# %% [markdown]
# ## 一元多项式的运算

# %% [markdown]
# ### Pn(x) = p0 + p1X + p2X^2 + ... + piXi + ... + pnX^n

# %%
"""
线性表 P = (p0, p1, p2, ..., pn)
每一项的指数 i 隐藏在其系数 pi 的序号中
例如 P(x) = 10 + 5X - 4X^2 + 3X^3 + 2X^4
"""
p = [10, 5, -4, 3, 2] # 用数组表示，下标 i --> 指数, p[i] --> 系数的值

# %% [markdown]
# ## 稀疏多项式的运算

# %% [markdown]
# S(X) = 1 + 5X^10000 - 7X^20000

# %%
P = [[1, 0], [5, 10000], [-7, 20000]]

# %% [markdown]
# 两个多项式非零项的数组表示
# - A(X) = 7 + 3X + 9X^8 + 5X^17
# - B(X) = 8X + 22X^7 - 9X^8

# %%
a = []
b = []

# 计算相加后的新数组 C
c = []

# 思考，数组 C 的长度最大和最小可以是多少？

# %% [markdown]
# ## 顺序存储结构存在的问题

# %% [markdown]
# - 存储空间分配不灵活
# - 运算的空间复杂度高
# - `解决方案`：链式存储结构
# - ![image.png](attachment:image.png)

# %%
class Node:
    def __init__(self, data, next):
        self.data = data
        self.next = next

# TOOD
class LinkedList:
    pass

# %% [markdown]
# ## 图书管理系统

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 解决方案
# ![image.png](attachment:image.png)

# %% [markdown]
# # 总结

# %% [markdown]
# - 线性表中的`数据元素`的类型可以为`简单类型`（多项式运算案例,如整数 `int` 或小数 `float`），也可以为`复杂类型`（图书系统案例，如图书的序列号，书名，价格等等）
# - 许多实际应用问题所涉及的基本操作有很大的相似性，不应为每个具体应用单独编写一个程序
# - 从具体的应用中`抽象`出共性的`逻辑结构`和`基本操作`(抽象数据类型)，然后实现其`存储结构`和`基本操作`
